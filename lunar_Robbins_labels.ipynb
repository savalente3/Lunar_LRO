# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# %%
# Set the path to the file you'd like to load
file_path = ""

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "sujaykapadnis/moon-crater-database-v1-robbins",
  file_path,
)


print("First 5 records:", df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       1 # Set the path to the file you'd like to load
#       2 file_path = ""
#       3
#       4 # Load the latest version
# ----> 5 df = kagglehub.load_dataset(
#       6   KaggleDatasetAdapter.PANDAS,
#       7   "sujaykapadnis/moon-crater-database-v1-robbins",
#       8   file_path,
#
# File ~/miniconda3/envs/lunar_lro/lib/python3.11/site-packages/kagglehub/datasets.py:119, in load_dataset(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs)
#     116 elif adapter is KaggleDatasetAdapter.PANDAS:
#     117     import kagglehub.pandas_datasets
# --> 119     return kagglehub.pandas_datasets.load_pandas_dataset(
#     120         handle, path, pandas_kwargs=pandas_kwargs, sql_query=sql_query
#     121     )
#     122 else:
#     123     not_implemented_error_message = f"{adapter} is not yet implemented"
#
# File ~/miniconda3/envs/lunar_lro/lib/python3.11/site-packages/kagglehub/pandas_datasets.py:87, in load_pandas_dataset(handle, path, pandas_kwargs, sql_query)
#      85 pandas_kwargs = {} if pandas_kwargs is None else pandas_kwargs
#      86 file_extension = os.path.splitext(path)[1]
# ---> 87 read_function = _validate_read_function(file_extension, sql_query)
#      89 # Now that everything has been validated, we can start downloading and processing
#      90 filepath = dataset_download(handle, path)
#
# File ~/miniconda3/envs/lunar_lro/lib/python3.11/site-packages/kagglehub/pandas_datasets.py:109, in _validate_read_function(file_extension, sql_query)
#     104 if file_extension not in SUPPORTED_READ_FUNCTIONS_BY_EXTENSION:
#     105     extension_error_message = (
#     106         f"Unsupported file extension: '{file_extension}'. "
#     107         f"Supported file extensions are: {', '.join(SUPPORTED_READ_FUNCTIONS_BY_EXTENSION.keys())}"
#     108     )
# --> 109     raise ValueError(extension_error_message) from None
#     111 read_function = SUPPORTED_READ_FUNCTIONS_BY_EXTENSION[file_extension]
#     112 if read_function is wrapped_read_sql_query and not sql_query:
#
# ValueError: Unsupported file extension: ''. Supported file extensions are: .csv, .tsv, .json, .jsonl, .xml, .parquet, .feather, .sqlite, .sqlite3, .db, .db3, .s3db, .dl3, .xls, .xlsx, .xlsm, .xlsb, .odf, .ods, .odt

# %%
headers = {"Authorization": f"Bearer {os.environ['NASA_EARTHDATA_TOKEN']}"}
