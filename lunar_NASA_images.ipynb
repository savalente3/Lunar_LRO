# %%
import requests
import os

# %%
headers = {"Authorization": f"Bearer {os.environ['NASA_EARTHDATA_TOKEN']}"}

response = requests.get(
    "https://cmr.earthdata.nasa.gov/search/granules.json",
    headers=headers,
    params={
        "short_name": "LRO_LROC_CDR",
        "bounding_box": "-180,-90,180,90",
        "page_size": 10
    }
)

print(response.json())
# Out:
# {'feed': {'updated': '2026-06-01T21:08:25.518Z', 'id': 'https://cmr.earthdata.nasa.gov:443/search/granules.json?short_name=LRO_LROC_CDR&bounding_box=-180%2C-90%2C180%2C90&page_size=10', 'title': 'ECHO granule metadata', 'entry': []}}
